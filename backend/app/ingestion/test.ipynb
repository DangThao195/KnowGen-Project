# %%
# %pip install pymupdf4llm
# Out:
# Requirement already satisfied: pymupdf4llm in c:\users\huuda\anaconda3\lib\site-packages (1.27.2.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pymupdf==1.27.2.2 in c:\users\huuda\anaconda3\lib\site-packages (from pymupdf4llm) (1.27.2.2)
# Requirement already satisfied: pymupdf_layout==1.27.2.2 in c:\users\huuda\anaconda3\lib\site-packages (from pymupdf4llm) (1.27.2.2)
# Requirement already satisfied: tabulate in c:\users\huuda\anaconda3\lib\site-packages (from pymupdf4llm) (0.9.0)
# Requirement already satisfied: pyyaml in c:\users\huuda\anaconda3\lib\site-packages (from pymupdf_layout==1.27.2.2->pymupdf4llm) (6.0.2)
# Requirement already satisfied: numpy in c:\users\huuda\anaconda3\lib\site-packages (from pymupdf_layout==1.27.2.2->pymupdf4llm) (2.1.3)
# Requirement already satisfied: onnxruntime in c:\users\huuda\anaconda3\lib\site-packages (from pymupdf_layout==1.27.2.2->pymupdf4llm) (1.24.4)
# Requirement already satisfied: networkx in c:\users\huuda\anaconda3\lib\site-packages (from pymupdf_layout==1.27.2.2->pymupdf4llm) (3.4.2)
# Requirement already satisfied: flatbuffers in c:\users\huuda\anaconda3\lib\site-packages (from onnxruntime->pymupdf_layout==1.27.2.2->pymupdf4llm) (25.12.19)
# Requirement already satisfied: packaging in c:\users\huuda\anaconda3\lib\site-packages (from onnxruntime->pymupdf_layout==1.27.2.2->pymupdf4llm) (24.2)
# Requirement already satisfied: protobuf in c:\users\huuda\anaconda3\lib\site-packages (from onnxruntime->pymupdf_layout==1.27.2.2->pymupdf4llm) (5.29.3)
# Requirement already satisfied: sympy in c:\users\huuda\anaconda3\lib\site-packages (from onnxruntime->pymupdf_layout==1.27.2.2->pymupdf4llm) (1.13.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\huuda\anaconda3\lib\site-packages (from sympy->onnxruntime->pymupdf_layout==1.27.2.2->pymupdf4llm) (1.3.0)

# %%
# %pip install langchain_text_splitters
# Out:
# Requirement already satisfied: langchain_text_splitters in c:\users\huuda\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.13 in c:\users\huuda\anaconda3\lib\site-packages (from langchain_text_splitters) (1.2.23)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.10.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (9.0.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\huuda\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.32.3)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.23.0)
# Requirement already satisfied: anyio in c:\users\huuda\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (4.13.0)
# Requirement already satisfied: certifi in c:\users\huuda\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\huuda\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\huuda\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\huuda\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\huuda\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\huuda\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\huuda\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\huuda\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain_text_splitters) (2.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain_google_genai
# Out:
# Requirement already satisfied: langchain_google_genai in c:\users\huuda\anaconda3\lib\site-packages (4.2.1)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain_google_genai) (1.69.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in c:\users\huuda\anaconda3\lib\site-packages (from langchain_google_genai) (1.2.23)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain_google_genai) (2.10.3)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\huuda\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\huuda\anaconda3\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.49.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\huuda\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\huuda\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.32.3)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\huuda\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (9.0.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\huuda\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\huuda\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\huuda\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\huuda\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\huuda\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\huuda\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\huuda\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (44.0.1)
# Requirement already satisfied: certifi in c:\users\huuda\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\huuda\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\huuda\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (6.0.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\huuda\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\huuda\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\huuda\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.5->langchain_google_genai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\huuda\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\huuda\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\huuda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\huuda\anaconda3\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.3.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\huuda\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\huuda\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (2.21)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\huuda\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<2.0.0,>=1.56.0->langchain_google_genai) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import json
from IPython.display import display, Markdown

# 0. Sửa lỗi "ModuleNotFoundError: No module named 'app'" khi chạy trong thư mục con
sys.path.append(os.path.abspath("../../"))

from app.ingestion.extract import Document
from app.ingestion.transform import transform_documents

json_file = "extracted_metadata.json"

# 1. Nạp dữ liệu
try:
    with open(json_file, "r", encoding="utf-8") as f:
        raw_dicts = json.load(f)
    print(f"✅ Đã tải file JSON ({len(raw_dicts)} bản ghi)\n")
except FileNotFoundError:
    print(f"❌ Không tìm thấy file {json_file}.")
    raw_dicts = []

# ==========================================
# 2. CHUYỂN JSON DICT THÀNH OBJECT PYDANTIC
# ==========================================
documents_to_transform = [Document(**d) for d in raw_dicts]

# 3. Test hàm Transform
print("🔄 Đang chạy Pipeline Transform (Clean -> Summarize -> Chunk)...\n")
transformed_results = transform_documents(documents_to_transform)

# 4. Hiển thị kết quả Transform
print(f"✅ Đã xong! Transform được {len(transformed_results)} tài liệu.\n")

for i, t_doc in enumerate(transformed_results):
    print("="*80)
    print(f"🚀 KẾT QUẢ TRANSFORM TÀI LIỆU SỐ {i+1} : {t_doc.title}")
    print(f"📦 Tổng số chunks : {len(t_doc.chunks)}")
    print("-"*80)
    
    # In chi tiết từng chunk ra xem thử
    for chunk in t_doc.chunks:
        role = chunk.metadata.get('role', 'unknown')
        header_path = chunk.metadata.get('header_path', 'N/A')
        
        print(f"🔹 [Chunk {chunk.chunk_index}] - Role: {role.upper()} | Path: {header_path}")
        # Rút gọn nội dung (in 150 ký tự đầu tiên để test)
        preview = chunk.content[:300].replace('\n', ' ') + "..."
        print(f"   Nội dung: {preview}\n")
# Out:
# ✅ Đã tải file JSON (1 bản ghi)
#
# 🔄 Đang chạy Pipeline Transform (Clean -> Summarize -> Chunk)...
# INFO:app.ingestion.transform:Transforming document: 102230316_HuynhBaoQuyen_23TDT3.docx
# INFO:google_genai.models:AFC is enabled with max remote calls: 10.
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 200 OK"
# INFO:app.ingestion.transform:Done '102230316_HuynhBaoQuyen_23TDT3.docx': summary=ok, chunks=12
# ✅ Đã xong! Transform được 1 tài liệu.
#
# ================================================================================
# 🚀 KẾT QUẢ TRANSFORM TÀI LIỆU SỐ 1 : 102230316_HuynhBaoQuyen_23TDT3.docx
# 📦 Tổng số chunks : 12
# --------------------------------------------------------------------------------
# 🔹 [Chunk 0] - Role: SUMMARY | Path: N/A
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 1] - Role: CHUNK | Path: đại học đà nẵng trường đại học bách khoa
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 2] - Role: CHUNK | Path: gvhd:ts. trịnh công duy
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 3] - Role: CHUNK | Path: mở đầu
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 4] - Role: CHUNK | Path: agi và trách nhiệm của con người > agi là gì?
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 5] - Role: CHUNK | Path: agi và trách nhiệm của con người > agi có thể làm gì?
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 6] - Role: CHUNK | Path: agi và trách nhiệm của con người > tại sao agi không thể chịu trách nhiệm?
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 7] - Role: CHUNK | Path: agi và trách nhiệm của con người > tầm quan trọng của quyền phán đoán giá trị trong dự án kỹ thuật có ai
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 8] - Role: CHUNK | Path: agi và trách nhiệm của con người > nguy cơ “automation bias” – khi con người quá tin vào ai
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 9] - Role: CHUNK | Path: agi và trách nhiệm của con người > “human-in-the-loop” trong kỷ nguyên agi
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 10] - Role: CHUNK | Path: cam kết và hành động
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
#
# 🔹 [Chunk 11] - Role: CHUNK | Path: thông điệp gửi đến tương lai
#    Nội dung: Summary of 102230316_HuynhBaoQuyen_23TDT3.docx: Báo cáo phân tích sâu về Trí tuệ tổng quát nhân tạo (AGI), nhấn mạnh khả năng học hỏi, suy luận và giải quyết mọi vấn đề trí tuệ phức tạp của nó. Tuy nhiên, tài liệu lập luận mạnh mẽ rằng AGI không thể chịu trách nhiệm pháp lý và đạo đức do thiếu lương...
