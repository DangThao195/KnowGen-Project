# %%
import sys
import os

# Add backend to sys.path for direct imports from notebooks
backend_dir = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
if backend_dir not in sys.path:
    sys.path.append(backend_dir)

from app.ingestion.etl import run_etl_pipeline
from app.agents.supervisor_agent import supervisor_node
from app.agents.multi_agent import AgentState
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 9
#       6 if backend_dir not in sys.path:
#       7     sys.path.append(backend_dir)
# ----> 9 from app.ingestion.etl import run_etl_pipeline
#      10 from app.agents.supervisor_agent import supervisor_node
#      11 from app.agents.multi_agent import AgentState
#
# File d:\KnowGen-Project\backend\app\ingestion\etl.py:10
#       8 from app.ingestion.extract import Document, extract_pdf_to_md, extract_docx_to_md, extract_notion_to_md
#       9 from app.ingestion.transform import transform_documents
# ---> 10 from app.ingestion.load import load_documents_to_faiss
#      12 # Load environment variables (adjust path if needed)
#      13 load_dotenv(os.path.join(os.path.dirname(os.getcwd()), '.env'))
#
# File d:\KnowGen-Project\backend\app\ingestion\load.py:8
#       6 # LangChain and Vectorstore imports
# ...

# %% [markdown]
# ### 1. Run ETL Pipeline

# %%
# Run the ETL pipeline on a sample file
sample_file = "C:\\Users\\huuda\\Downloads\\a.thuvienvatly.com.2160e.47524.pdf"
run_etl_pipeline(file_paths=[sample_file]) # Uncomment to execute pipeline
print("ETL Pipeline block ready.")

# %% [markdown]
# ### 2. Test Supervisor Node

# %%
# Initialize state with a test query
state: AgentState = {"user_query": "Tạo một bài quiz trắc nghiệm 5 câu về các khái niệm trong tài liệu trên."}

# Run the supervisor node
updated_fields = supervisor_node(state)

# Update state with output fields
state.update(updated_fields)

# Print all attribute values in state as requested
print("--- State after Supervisor Node ---")
for key, value in state.items():
    print(f"\n{key.upper()}:")
    print(value)
